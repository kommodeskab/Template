# %%
api_key = "osoJRyh0LcOZcjkXnbA3GaFJ"
user_id = '17728906'
collection_id = '94PBI4D8'

# %%
import requests
import os

def update_zotero_bib(
    user_id : str,
    collection_id : str | None = None,
    api_key : str | None = None
) -> None:
    base_url = f"https://api.zotero.org/users/{user_id}"

    if api_key is None:
        assert (api_key := os.environ['ZOTERO_API_KEY']) is not None, "ZOTERO_API_KEY environment variable not set"

    if collection_id:
        url = f"{base_url}/collections/{collection_id}/items"
    else:
        url = f"{base_url}/items"

    headers = {'Zotero-API-Key': api_key}
    params = {'format': 'bibtex'}
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        bibtex_content = response.text
        with open("zotero_refs.bib", "w", encoding="utf-8") as f:
            f.write(bibtex_content)

        print("Saved to zotero_refs.bib")
    else:
        print("Error:", response.status_code, response.text)
        
update_zotero_bib(
    user_id="17728906",
    collection_id="94PBI4D8"
)
# Out:
# Saved to zotero_refs.bib
